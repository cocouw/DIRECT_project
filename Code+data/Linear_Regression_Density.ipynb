# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.loadtxt('Density.txt')
n = X.shape[0]
d = X.shape[1]
d -= 1
print(n,d)
# Out:
# 510 190

# %%
n_train = int(n*0.8)
n_test  = n - n_train
print('ntrain',n_train,'ntest',n_test)
X = np.random.permutation(X)

X_train = np.zeros((n_train,d+1))
X_test  = np.zeros((n_test,d+1))
Y_train = np.zeros((n_train))
Y_test = np.zeros((n_test))


b = np.ones(n_train)
X_train[:,:-1] = X[:n_train,:-1]
X_train[:,-1] = b
Y_train[:] = X[:n_train,-1]


b = np.ones(n_test)
X_test[:,:-1] = X[n_train:,:-1]
X_test[:,-1] = b
Y_test[:] = X[n_train:,-1]

print(X_train.shape)
print(X_test.shape)
# Out:
# ntrain 408 ntest 102
# (408, 191)
# (102, 191)

# %%
w = np.dot(np.dot(np.linalg.pinv(np.dot(np.transpose(X_train),X_train)), np.transpose(X_train)), Y_train)

# %%
y_train = X_train.dot(w)
plt.plot(Y_train,y_train,"o",color ='pink')
plt.plot(np.arange(900,1600),np.arange(900,1600),color = 'black')
plt.axis([900,1600,900,1600])
plt.xlabel('experiment value')
plt.ylabel('prediction')
plt.title('Prediction on training data')
plt.show()

# %%
y_test = X_test.dot(w)
plt.plot(Y_test,y_test,"o",color ='pink')
plt.plot(np.arange(900,1600),np.arange(900,1600),color = 'black')
plt.axis([900,1600,900,1600])
plt.xlabel('experiment value')
plt.ylabel('prediction')
plt.title('prediction on test data')
plt.show()
